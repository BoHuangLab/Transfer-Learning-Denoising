# %% [markdown]
# # Single-Shot CNN Denoising
#
# We demonstrate that a deep neural net can be trained to denoise a _single_ noisy image, taking advantage of the fact that one 512 x 512 image contains ~250,000 dimensions of information.

# %%
IMAGE_PATH =
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from util import show, plot_images, plot_tensors, addnoise

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.morphology import disk
from skimage.filters import gaussian, median
from skimage import data, img_as_float, img_as_ubyte
from skimage.color import gray2rgb
from skimage.util import random_noise
from skimage.measure import compare_psnr

# %%
plt.rc('figure', figsize = (5,5))

# %%
# Out:
# 47 movies were saved.

# %%
np.random.seed(3)
noisy_image = addnoise(image, 10, 3)
show(noisy_image)

# %%
import torch
noisy = torch.Tensor(noisy_image[np.newaxis, np.newaxis])

# %%
from util import getbestgpu
device = getbestgpu(1)
# Out:
# GPU device 0 has 6018 MiB left.
# --> GPU device 0 was chosen

# %% [markdown]
# # Masking
#
# The strategy is to train a $J$-invariant version of a neural net by replacing a grid of pixels with the average of their neighbors, then only evaluating the model on the masked pixels.

# %%
from mask import Masker
masker = Masker(width = 4, mode='interpolate')

# %% [markdown]
# # Model

# %% [markdown]
# For our model, we use a deep convolutional network.

# %%
torch.manual_seed(3)
from models.unet import Unet
model = Unet()

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 3325355

# %%
image.ravel().shape
# Out:
# (65536,)

# %% [markdown]
# # Training

# %%
from torch.nn import MSELoss, L1Loss
from torch.optim import Adam

loss_function = MSELoss()
optimizer = Adam(model.parameters(), lr=0.001)

# %%
model = model.to(device)
noisy = noisy.to(device)

# %%
losses = []
val_losses = []
best_images = []
best_val_loss = 1

for i in range(500):
    model.train()
    
    net_input, mask = masker.mask(noisy, i % (masker.n_masks - 1))
    net_output = model(net_input)
    
    loss = loss_function(net_output*mask, noisy*mask)
    optimizer.zero_grad()
 
    loss.backward()
    
    optimizer.step()
    
    if i % 10 == 0:
        losses.append(loss.item())
        model.eval()
        
        net_input, mask = masker.mask(noisy, i % (masker.n_masks - 1))
        net_output = model(net_input)
    
        val_loss = loss_function(net_output*mask, noisy*mask)
        
        val_losses.append(val_loss.item())
        
        print("(", i, ") Loss: \t", round(loss.item(), 5), "\tVal Loss: \t", round(val_loss.item(), 5))

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            denoised = np.clip(model(noisy).detach().cpu().numpy()[0, 0], 0, 1).astype(np.float64)
            best_psnr = compare_psnr(denoised, image)
            best_images.append(denoised)
            print("\tModel PSNR: ", np.round(best_psnr, 2))
# Out:
# ( 0 ) Loss: 	 0.00951 	Val Loss: 	 0.00951
# 	Model PSNR:  16.16
# /home/yina/envs/n2s/lib/python3.7/site-packages/skimage/measure/simple_metrics.py:127: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im_true.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# ( 10 ) Loss: 	 0.0044 	Val Loss: 	 0.00196
# 	Model PSNR:  9.63
# ( 20 ) Loss: 	 0.00181 	Val Loss: 	 0.0019
# 	Model PSNR:  9.43
# ( 30 ) Loss: 	 0.00182 	Val Loss: 	 0.00183
# 	Model PSNR:  10.49
# ( 40 ) Loss: 	 0.00178 	Val Loss: 	 0.00177
# 	Model PSNR:  10.74
# ( 50 ) Loss: 	 0.00174 	Val Loss: 	 0.00174
# 	Model PSNR:  10.8
# ( 60 ) Loss: 	 0.00181 	Val Loss: 	 0.00181
# ( 70 ) Loss: 	 0.00173 	Val Loss: 	 0.00173
# 	Model PSNR:  11.06
# ( 80 ) Loss: 	 0.00172 	Val Loss: 	 0.00172
# 	Model PSNR:  10.8
# ( 90 ) Loss: 	 0.0018 	Val Loss: 	 0.00179
# ( 100 ) Loss: 	 0.00168 	Val Loss: 	 0.00167
# 	Model PSNR:  11.09
# ( 110 ) Loss: 	 0.0017 	Val Loss: 	 0.0017
# ( 120 ) Loss: 	 0.00176 	Val Loss: 	 0.00177
# ( 130 ) Loss: 	 0.00164 	Val Loss: 	 0.00164
# 	Model PSNR:  11.14
# ( 140 ) Loss: 	 0.0017 	Val Loss: 	 0.0017
# ( 150 ) Loss: 	 0.00176 	Val Loss: 	 0.00175
# ( 160 ) Loss: 	 0.00164 	Val Loss: 	 0.00163
# 	Model PSNR:  10.93
# ( 170 ) Loss: 	 0.0017 	Val Loss: 	 0.0017
# ( 180 ) Loss: 	 0.00174 	Val Loss: 	 0.00174
# ( 190 ) Loss: 	 0.00164 	Val Loss: 	 0.00164
# ( 200 ) Loss: 	 0.00169 	Val Loss: 	 0.00169
# ( 210 ) Loss: 	 0.00173 	Val Loss: 	 0.00175
# ( 220 ) Loss: 	 0.00164 	Val Loss: 	 0.00164
# ( 230 ) Loss: 	 0.0017 	Val Loss: 	 0.00169
# ( 240 ) Loss: 	 0.00175 	Val Loss: 	 0.00175
# ( 250 ) Loss: 	 0.00165 	Val Loss: 	 0.00163
# 	Model PSNR:  11.01
# ( 260 ) Loss: 	 0.00171 	Val Loss: 	 0.00177
# ( 270 ) Loss: 	 0.00185 	Val Loss: 	 0.00173
# ( 280 ) Loss: 	 0.00182 	Val Loss: 	 0.00188
# ( 290 ) Loss: 	 0.00197 	Val Loss: 	 0.00171
# ( 300 ) Loss: 	 0.00177 	Val Loss: 	 0.00192
# ( 310 ) Loss: 	 0.00168 	Val Loss: 	 0.00166
# ( 320 ) Loss: 	 0.00169 	Val Loss: 	 0.00169
# ( 330 ) Loss: 	 0.00175 	Val Loss: 	 0.00175
# ( 340 ) Loss: 	 0.00163 	Val Loss: 	 0.00163
# ( 350 ) Loss: 	 0.0017 	Val Loss: 	 0.0017
# ( 360 ) Loss: 	 0.00174 	Val Loss: 	 0.00174
# ( 370 ) Loss: 	 0.00163 	Val Loss: 	 0.00163
# ( 380 ) Loss: 	 0.0017 	Val Loss: 	 0.0017
# ( 390 ) Loss: 	 0.00173 	Val Loss: 	 0.00174
# ( 400 ) Loss: 	 0.00163 	Val Loss: 	 0.00162
# 	Model PSNR:  10.92
# ( 410 ) Loss: 	 0.00169 	Val Loss: 	 0.00169
# ( 420 ) Loss: 	 0.00173 	Val Loss: 	 0.00173
# ( 430 ) Loss: 	 0.00162 	Val Loss: 	 0.00163
# ( 440 ) Loss: 	 0.00169 	Val Loss: 	 0.00168
# ( 450 ) Loss: 	 0.00173 	Val Loss: 	 0.00173
# ( 460 ) Loss: 	 0.00162 	Val Loss: 	 0.00163
# ( 470 ) Loss: 	 0.00168 	Val Loss: 	 0.00168
# ( 480 ) Loss: 	 0.00173 	Val Loss: 	 0.00172
# ( 490 ) Loss: 	 0.00162 	Val Loss: 	 0.00162
# 	Model PSNR:  10.61

# %%
plot_images(best_images[::2])

# %%
denoised = best_images[-1]

# %%
compare_psnr(denoised, image)
# Out:
# 10.605516896750068

# %%
compare_psnr(noisy_image, image)
# Out:
# 9.825198515868243

# %%
inset_x_min = 100
inset_x_max = 160
inset_y_min = 150
inset_y_max = 250

get_inset = lambda x: x[inset_x_min:inset_x_max, inset_y_min:inset_y_max]

# %%
plot_images([denoised, noisy_image, image])

# %%
plot_images([get_inset(denoised), get_inset(noisy_image), get_inset(image)])

# %%
plot_images([get_inset(denoised), get_inset(noisy_image), get_inset(image)])

# %%
last_output = net_output
plot_tensors([mask, noisy, net_input, net_input - noisy, last_output],
            ["Mask", "Noisy Image", "Neural Net Input", "Difference", "Last Neural Net Output"])

# %%
print(loss_function(net_output*mask, noisy*mask))
plot_tensors([net_output*mask - noisy*mask, mask], ["loss difference", "mask"])
# Out:
# tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)
