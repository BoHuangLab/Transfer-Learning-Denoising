# %% [markdown]
# # Single-Shot CNN Denoising
#
# We demonstrate that a deep neural net can be trained to denoise a _single_ noisy image, taking advantage of the fact that one 512 x 512 image contains ~250,000 dimensions of information.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")

# %%
from util import show, plot_images, plot_tensors

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.morphology import disk
from skimage.filters import gaussian, median
from skimage import data, img_as_float, img_as_ubyte
from skimage.color import gray2rgb
from skimage.util import random_noise
from skimage.measure import compare_psnr

# %%
plt.rc('figure', figsize = (5,5))

# %%
file_path = '/home/yina/DeepDenoising/TimelapseDenoise/Experimental_data/testing/'
try:
    data = np.load(file_path+'highSNR.npz')
    print("{} movies were saved.".format(data['highSNR'].shape[0]))
except:
    raise("Data not existed.")

# %%
np.random.seed(3)
noisy_image = random_noise(image, mode = 'gaussian', var=0.01)
show(noisy_image)

# %%
import torch
noisy = torch.Tensor(noisy_image[np.newaxis, np.newaxis])

# %%
from util import getbestgpu
device = getbestgpu(1)
# Out:
# GPU device 0 has 3499 MiB left.
# --> GPU device 0 was chosen

# %% [markdown]
# # Masking
#
# The strategy is to train a $J$-invariant version of a neural net by replacing a grid of pixels with the average of their neighbors, then only evaluating the model on the masked pixels.

# %%
from mask import Masker
masker = Masker(width = 4, mode='interpolate')

# %% [markdown]
# # Model

# %% [markdown]
# For our model, we use a deep convolutional network.

# %%
torch.manual_seed(3)
from models.dncnn import DnCNN
model = DnCNN(1, num_of_layers = 16)

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 519040

# %%
image.ravel().shape
# Out:
# (262144,)

# %% [markdown]
# # Training

# %%
from torch.nn import MSELoss, L1Loss
from torch.optim import Adam

loss_function = MSELoss()
optimizer = Adam(model.parameters(), lr=0.01)

# %%
model = model.to(device)
noisy = noisy.to(device)

# %%
losses = []
val_losses = []
best_images = []
best_val_loss = 1

for i in range(500):
    model.train()
    
    net_input, mask = masker.mask(noisy, i % (masker.n_masks - 1))
    net_output = model(net_input)
    
    loss = loss_function(net_output*mask, noisy*mask)
    optimizer.zero_grad()
 
    loss.backward()
    
    optimizer.step()
    
    if i % 10 == 0:
        losses.append(loss.item())
        model.eval()
        
        net_input, mask = masker.mask(noisy, i % (masker.n_masks - 1))
        net_output = model(net_input)
    
        val_loss = loss_function(net_output*mask, noisy*mask)
        
        val_losses.append(val_loss.item())
        
        print("(", i, ") Loss: \t", round(loss.item(), 5), "\tVal Loss: \t", round(val_loss.item(), 5))

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            denoised = np.clip(model(noisy).detach().cpu().numpy()[0, 0], 0, 1).astype(np.float64)
            best_psnr = compare_psnr(denoised, image)
            best_images.append(denoised)
            print("\tModel PSNR: ", np.round(best_psnr, 2))
# Out:
# ( 0 ) Loss: 	 0.02211 	Val Loss: 	 0.01618
# 	Model PSNR:  6.02
# ( 10 ) Loss: 	 0.00149 	Val Loss: 	 174.85663
# ( 20 ) Loss: 	 0.00088 	Val Loss: 	 1.77873
# ( 30 ) Loss: 	 0.00082 	Val Loss: 	 0.01973
# ( 40 ) Loss: 	 0.00076 	Val Loss: 	 0.00122
# 	Model PSNR:  20.07
# ( 50 ) Loss: 	 0.00071 	Val Loss: 	 0.00087
# 	Model PSNR:  23.0
# ( 60 ) Loss: 	 0.00073 	Val Loss: 	 0.00082
# 	Model PSNR:  24.23
# ( 70 ) Loss: 	 0.00072 	Val Loss: 	 0.00082
# 	Model PSNR:  23.89
# ( 80 ) Loss: 	 0.00069 	Val Loss: 	 0.00078
# 	Model PSNR:  23.95
# ( 90 ) Loss: 	 0.00071 	Val Loss: 	 0.00079
# ( 100 ) Loss: 	 0.00071 	Val Loss: 	 0.0008
# ( 110 ) Loss: 	 0.00068 	Val Loss: 	 0.00074
# 	Model PSNR:  24.73
# ( 120 ) Loss: 	 0.00069 	Val Loss: 	 0.0007
# 	Model PSNR:  26.45
# ( 130 ) Loss: 	 0.0007 	Val Loss: 	 0.00074
# ( 140 ) Loss: 	 0.00067 	Val Loss: 	 0.00069
# 	Model PSNR:  26.2
# ( 150 ) Loss: 	 0.00067 	Val Loss: 	 0.00067
# 	Model PSNR:  27.25
# ( 160 ) Loss: 	 0.00068 	Val Loss: 	 0.00077
# ( 170 ) Loss: 	 0.00067 	Val Loss: 	 0.00067
# 	Model PSNR:  26.93
# ( 180 ) Loss: 	 0.00066 	Val Loss: 	 0.00067
# ( 190 ) Loss: 	 0.00068 	Val Loss: 	 0.00067
# ( 200 ) Loss: 	 0.00066 	Val Loss: 	 0.00065
# 	Model PSNR:  27.84
# ( 210 ) Loss: 	 0.00065 	Val Loss: 	 0.00067
# ( 220 ) Loss: 	 0.00066 	Val Loss: 	 0.00066
# ( 230 ) Loss: 	 0.00065 	Val Loss: 	 0.00065
# 	Model PSNR:  28.43
# ( 240 ) Loss: 	 0.00064 	Val Loss: 	 0.00064
# 	Model PSNR:  28.52
# ( 250 ) Loss: 	 0.00065 	Val Loss: 	 0.00068
# ( 260 ) Loss: 	 0.00064 	Val Loss: 	 0.00064
# ( 270 ) Loss: 	 0.00063 	Val Loss: 	 0.00063
# 	Model PSNR:  28.8
# ( 280 ) Loss: 	 0.00065 	Val Loss: 	 0.00065
# ( 290 ) Loss: 	 0.00064 	Val Loss: 	 0.00064
# ( 300 ) Loss: 	 0.00063 	Val Loss: 	 0.00063
# 	Model PSNR:  29.14
# ( 310 ) Loss: 	 0.00065 	Val Loss: 	 0.00066
# ( 320 ) Loss: 	 0.00063 	Val Loss: 	 0.00063
# ( 330 ) Loss: 	 0.00063 	Val Loss: 	 0.00063
# ( 340 ) Loss: 	 0.00064 	Val Loss: 	 0.00065
# ( 350 ) Loss: 	 0.00063 	Val Loss: 	 0.00063
# ( 360 ) Loss: 	 0.00063 	Val Loss: 	 0.00065
# ( 370 ) Loss: 	 0.00065 	Val Loss: 	 0.00066
# ( 380 ) Loss: 	 0.00062 	Val Loss: 	 0.00063
# ( 390 ) Loss: 	 0.00063 	Val Loss: 	 0.00064
# ( 400 ) Loss: 	 0.00064 	Val Loss: 	 0.00064
# ( 410 ) Loss: 	 0.00062 	Val Loss: 	 0.00063
# 	Model PSNR:  29.9
# ( 420 ) Loss: 	 0.00064 	Val Loss: 	 0.00066
# ( 430 ) Loss: 	 0.00065 	Val Loss: 	 0.00065
# ( 440 ) Loss: 	 0.00062 	Val Loss: 	 0.00062
# 	Model PSNR:  29.85
# ( 450 ) Loss: 	 0.00062 	Val Loss: 	 0.00064
# ( 460 ) Loss: 	 0.00064 	Val Loss: 	 0.00063
# ( 470 ) Loss: 	 0.00063 	Val Loss: 	 0.00062
# ( 480 ) Loss: 	 0.00064 	Val Loss: 	 0.00065
# ( 490 ) Loss: 	 0.00065 	Val Loss: 	 0.00064

# %%
plot_images(best_images[::2])

# %%
denoised = best_images[-1]

# %%
compare_psnr(denoised, image)
# Out:
# 29.852929588960038

# %%
inset_x_min = 100
inset_x_max = 160
inset_y_min = 230
inset_y_max = 290

get_inset = lambda x: x[inset_x_min:inset_x_max, inset_y_min:inset_y_max]

# %%
show((denoised))

# %%
show(noisy_image)

# %%
last_output = net_output
plot_tensors([mask, noisy, net_input, net_input - noisy, last_output],
            ["Mask", "Noisy Image", "Neural Net Input", "Difference", "Last Neural Net Output"])

# %%
print(loss_function(net_output*mask, noisy*mask))
plot_tensors([net_output*mask - noisy*mask, mask], ["loss difference", "mask"])
# Out:
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)
