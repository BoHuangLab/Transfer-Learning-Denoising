# %% [markdown]
# # Train Unet on Simulation dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

from util import show, plot_images, plot_tensors, axes_dict_datasize
from data_loader_Sim import load_simulation

# %%
import torch

# %% [markdown]
# Load the FMD dataset

# %%
batch_size = 32
datasize = [batch_size,1,1,128,128]
axes = 'SCTXY'
structures = {'microtubule':10}
psignal_levels = [s for s in range(1,50,2)]

# %%
axes, datasize = axes_dict_datasize(axes, datasize)
print(axes)
# Out:
# {'S': 32, 'C': 1, 'T': 1, 'Z': 1, 'Y': 128, 'X': 128}

# %%
loader = load_simulation(batch_size, datasize, axes, structures, psignal_levels)

# %%
for i_batch, (noisy, clean) in enumerate(loader):
    print(i_batch, noisy.shape)
    print(i_batch, clean.shape)
    plot_tensors([noisy[0,0,:], clean[0,0,:]], ['Noisy Image', 'Clean Image'])
    break
# Out:
# 0 torch.Size([32, 1, 128, 128])
# 0 torch.Size([32, 1, 128, 128])

# %% [markdown]
# # Model

# %%
from models.unet import Unet
model = Unet(up='nearest')

# %% [markdown]
# # Training

# %%
from util import getbestgpu
device = getbestgpu(1)
# Out:
# GPU device 0 has 3091 MiB left.
# --> GPU device 0 was chosen

# %%
model = model.to(device)

# %%
from torch.nn import MSELoss
from torch.optim import Adam

loss_function = MSELoss()
optimizer = Adam(model.parameters(), lr=0.001)
n_epoch = 300

# %%
for epoch in range(n_epoch):
    
    for i, (noisy, clean) in enumerate(loader):
        noisy_images, clean_images = noisy.type(torch.FloatTensor).to(device), clean.type(torch.FloatTensor).to(device)
        
        optimizer.zero_grad()
    
        net_output = model(noisy_images)
        loss = loss_function(net_output, clean_images)
 
        loss.backward()
    
        optimizer.step()
    
         # print statistics
        print('[%d, %5d] loss: %.5f' % (epoch + 1, i + 1, loss.item()))
    
    if (epoch % 10 == 0):
        index = 30
        plot_tensors([noisy_images[index,0,:], net_output[index,0,:], clean_images[index,0,:]], ['Input','Output','Target'])

print('Finished Training')
# Out:
# [1,     1] loss: 0.02616
# [2,     1] loss: 1.71179
# [3,     1] loss: 0.03775
# [4,     1] loss: 0.02804
# [5,     1] loss: 0.03284
# [6,     1] loss: 0.03308
# [7,     1] loss: 0.03337
# [8,     1] loss: 0.03349
# [9,     1] loss: 0.03310
# [10,     1] loss: 0.03237
# [11,     1] loss: 0.03197
# [12,     1] loss: 0.02361
# [13,     1] loss: 0.06697
# [14,     1] loss: 0.02303
# [15,     1] loss: 0.02811
# [16,     1] loss: 0.02700
# [17,     1] loss: 0.02219
# [18,     1] loss: 0.02297
# [19,     1] loss: 0.02354
# [20,     1] loss: 0.02159
# [21,     1] loss: 0.02174
# [22,     1] loss: 0.02041
# [23,     1] loss: 0.02020
# [24,     1] loss: 0.02001
# [25,     1] loss: 0.01915
# [26,     1] loss: 0.01874
# [27,     1] loss: 0.01748
# [28,     1] loss: 0.01814
# [29,     1] loss: 0.01751
# [30,     1] loss: 0.01711
# [31,     1] loss: 0.01619
# [32,     1] loss: 0.01475
# [33,     1] loss: 0.01621
# [34,     1] loss: 0.01267
# [35,     1] loss: 0.01254
# [36,     1] loss: 0.01164
# [37,     1] loss: 0.01034
# [38,     1] loss: 0.00991
# [39,     1] loss: 0.01027
# [40,     1] loss: 0.00974
# [41,     1] loss: 0.00833
# [42,     1] loss: 0.00782
# [43,     1] loss: 0.00765
# [44,     1] loss: 0.00778
# [45,     1] loss: 0.00726
# [46,     1] loss: 0.00599
# [47,     1] loss: 0.00580
# [48,     1] loss: 0.00584
# [49,     1] loss: 0.00624
# [50,     1] loss: 0.00546
# [51,     1] loss: 0.00456
# [52,     1] loss: 0.00524
# [53,     1] loss: 0.00563
# [54,     1] loss: 0.00599
# [55,     1] loss: 0.00458
# [56,     1] loss: 0.00771
# [57,     1] loss: 0.00481
# [58,     1] loss: 0.00560
# [59,     1] loss: 0.00529
# [60,     1] loss: 0.00435
# [61,     1] loss: 0.00431
# [62,     1] loss: 0.00538
# [63,     1] loss: 0.00321
# [64,     1] loss: 0.00384
# [65,     1] loss: 0.00591
# [66,     1] loss: 0.00292
# [67,     1] loss: 0.00338
# [68,     1] loss: 0.00351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5afe1facd491> in <module>
#       1 for epoch in range(n_epoch):
#       2
# ----> 3     for i, (noisy, clean) in enumerate(loader):
#       4         noisy_images, clean_images = noisy.type(torch.FloatTensor).to(device), clean.type(torch.FloatTensor).to(device)
#       5
#
# ~/envs/n2s/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     574         while True:
#     575             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 576             idx, batch = self._get_batch()
#     577             self.batches_outstanding -= 1
#     578             if idx != self.rcvd_idx:
#
# ~/envs/n2s/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     541         elif self.pin_memory:
#     542             while self.pin_memory_thread.is_alive():
# --> 543                 success, data = self._try_get_batch()
#     544                 if success:
#     545                     return data
#
# ~/envs/n2s/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_batch(self, timeout)
#     509         #   (bool: whether successfully get data, any: data if successful else None)
#     510         try:
# --> 511             data = self.data_queue.get(timeout=timeout)
#     512             return (True, data)
#     513         except Exception as e:
#
# /usr/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
index = 30
plot_tensors([noisy_images[index,0,:], net_output[index,0,:], clean_images[index,0,:]], ['Input','Output','Target'])

# %%
torch.save(model.state_dict(), './models/MT_simulation_iter300_model_nearestup')
